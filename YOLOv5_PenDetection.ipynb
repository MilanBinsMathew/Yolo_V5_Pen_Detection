# %% [markdown]
# <a href="https://colab.research.google.com/github/MilanBinsMathew/Yolo_V5_Pen_Detection/blob/main/YOLOv5_PenDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pen-Detection using YOLOv5
#
# This project aims to detect pens in an image using the YOLO V5 model

# %% [markdown]
# ## 1. Setup the Environment
#
# Clone the YOLO v5 model developed by Ultralytics.
# Then install the required dependencies and frameworks for the project.

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch
import utils
display = utils.notebook_init()
# Out:
# INFO:yolov5:YOLOv5 🚀 v6.1-394-gd7bc5d7 Python-3.7.13 torch-1.12.1+cu113 CPU
# YOLOv5 🚀 v6.1-394-gd7bc5d7 Python-3.7.13 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.0/107.7 GB disk)

# %% [markdown]
# ## Import Dataset
#
# The dataset used for the project has been custom sourced and contains around 283 images for training and another 40 images for testing and validation respectively.
#
# The .zip file containing the images and labels in YOLO format are uploaded and then unzipped to the required directory.

# %%
# !ls ../
# Out:
# Pen_yolo.zip  yolov5

# %%
# !unzip -q ../Pen_yolo.zip -d ../

# %% [markdown]
# ## 2. Training
#
# Train the model with respect to the given data.
# Note arguments given may be modified depending upon the needs and requirements.

# %%
# !python train.py --img 640 --batch 8 --epochs 35 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=35, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 16 (delta 8), reused 16 (delta 8), pack-reused 0
# Unpacking objects: 100% (16/16), done.
# From https://github.com/ultralytics/yolov5
#    13ec336..5963a25  classifier -> origin/classifier
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-394-gd7bc5d7 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs in Weights & Biases
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 runs in ClearML
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(always_apply=False, p=0.01, blur_limit=(3, 7)), MedianBlur(always_apply=False, p=0.01, blur_limit=(3, 7)), ToGray(always_apply=False, p=0.01), CLAHE(always_apply=False, p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/yolov5/../Pen_yolo/train/labels.cache' images and labels... 283 found, 0 missing, 0 empty, 0 corrupt: 100% 283/283 [00:00<?, ?it/s]
# train: Caching images (0.3GB ram): 100% 283/283 [00:01<00:00, 165.51it/s]
# val: Scanning '/content/yolov5/../Pen_yolo/valid/labels.cache' images and labels... 28 found, 0 missing, 0 empty, 0 corrupt: 100% 28/28 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 28/28 [00:00<00:00, 51.96it/s]
# Plotting labels to runs/train/exp5/labels.jpg...
#
# AutoAnchor: 2.78 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 35 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/34        0G   0.09803    0.0278         0        11       640: 100% 36/36 [06:22<00:00, 10.61s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0% 0/2 [00:00<?, ?it/s]WARNING: NMS time limit 0.780s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50% 1/2 [00:08<00:08,  8.18s/it]WARNING: NMS time limit 0.660s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:14<00:00,  7.01s/it]
#                  all         28         28    0.00259       0.25    0.00903    0.00142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/34        0G   0.07161    0.0228         0         4       640: 100% 36/36 [06:12<00:00, 10.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0% 0/2 [00:00<?, ?it/s]WARNING: NMS time limit 0.780s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50% 1/2 [00:08<00:08,  8.21s/it]WARNING: NMS time limit 0.660s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:14<00:00,  7.02s/it]
#                  all         28         28     0.0283      0.536     0.0512     0.0156
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/34        0G   0.06457   0.02022         0         2       640: 100% 36/36 [06:16<00:00, 10.45s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:12<00:00,  6.36s/it]
#                  all         28         28     0.0448      0.571     0.0971     0.0199
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/34        0G    0.0614   0.01997         0         3       640: 100% 36/36 [06:13<00:00, 10.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:12<00:00,  6.30s/it]
#                  all         28         28      0.216      0.286      0.155      0.047
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/34        0G   0.05847   0.02077         0         3       640: 100% 36/36 [06:01<00:00, 10.04s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.67s/it]
#                  all         28         28      0.225       0.25      0.158     0.0509
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/34        0G   0.05477   0.01863         0         7       640: 100% 36/36 [05:43<00:00,  9.55s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.68s/it]
#                  all         28         28      0.185      0.286      0.179     0.0457
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/34        0G   0.05576   0.01903         0         6       640: 100% 36/36 [05:41<00:00,  9.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.81s/it]
#                  all         28         28      0.337      0.357      0.258     0.0834
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/34        0G   0.05152   0.01835         0         9       640: 100% 36/36 [05:51<00:00,  9.76s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.88s/it]
#                  all         28         28      0.387        0.5      0.379      0.121
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/34        0G   0.05188   0.01934         0         5       640: 100% 36/36 [05:55<00:00,  9.87s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.70s/it]
#                  all         28         28      0.709      0.349      0.431      0.169
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/34        0G   0.05211   0.01765         0         6       640: 100% 36/36 [05:53<00:00,  9.81s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:12<00:00,  6.20s/it]
#                  all         28         28      0.571      0.464      0.448      0.173
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/34        0G   0.04657   0.01658         0         5       640: 100% 36/36 [05:53<00:00,  9.82s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:12<00:00,  6.09s/it]
#                  all         28         28      0.679      0.607      0.641      0.214
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/34        0G   0.04781   0.01771         0         8       640: 100% 36/36 [05:48<00:00,  9.67s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:12<00:00,  6.24s/it]
#                  all         28         28      0.723      0.679      0.658      0.231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/34        0G   0.04584   0.01665         0         7       640: 100% 36/36 [05:59<00:00,  9.98s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.76s/it]
#                  all         28         28      0.582        0.5      0.561      0.243
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/34        0G   0.04483   0.01725         0         7       640: 100% 36/36 [05:57<00:00,  9.93s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.85s/it]
#                  all         28         28      0.843      0.536      0.634      0.257
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/34        0G   0.04479   0.01676         0         5       640: 100% 36/36 [05:55<00:00,  9.88s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.84s/it]
#                  all         28         28      0.672      0.571      0.609      0.224
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/34        0G   0.04721   0.01662         0         6       640: 100% 36/36 [05:58<00:00,  9.97s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.66s/it]
#                  all         28         28      0.746      0.628      0.724      0.299
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/34        0G   0.04117   0.01465         0         3       640: 100% 36/36 [05:54<00:00,  9.84s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.90s/it]
#                  all         28         28       0.66      0.625      0.639      0.299
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/34        0G   0.03799   0.01553         0         6       640: 100% 36/36 [05:56<00:00,  9.91s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.63s/it]
#                  all         28         28       0.57       0.75      0.677       0.25
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/34        0G   0.04266    0.0149         0         5       640: 100% 36/36 [05:45<00:00,  9.59s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.63s/it]
#                  all         28         28      0.676      0.607      0.665      0.259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/34        0G   0.04161    0.0155         0         4       640: 100% 36/36 [05:48<00:00,  9.69s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.70s/it]
#                  all         28         28      0.886      0.571       0.75      0.297
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/34        0G    0.0401   0.01513         0        10       640: 100% 36/36 [05:51<00:00,  9.76s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.75s/it]
#                  all         28         28      0.691      0.714      0.698      0.289
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/34        0G    0.0414   0.01558         0         7       640: 100% 36/36 [05:47<00:00,  9.64s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.69s/it]
#                  all         28         28      0.735      0.694      0.728      0.326
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/34        0G   0.03798   0.01535         0         8       640: 100% 36/36 [05:46<00:00,  9.63s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.73s/it]
#                  all         28         28      0.781       0.75      0.764      0.337
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/34        0G   0.03342   0.01377         0         5       640: 100% 36/36 [05:51<00:00,  9.77s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.73s/it]
#                  all         28         28        0.8      0.715      0.825      0.328
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/34        0G   0.03438   0.01421         0         3       640: 100% 36/36 [05:48<00:00,  9.67s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.69s/it]
#                  all         28         28      0.866      0.691      0.826      0.372
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/34        0G   0.03602   0.01395         0         5       640: 100% 36/36 [05:47<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.80s/it]
#                  all         28         28      0.715      0.821      0.821      0.368
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/34        0G    0.0326    0.0139         0         9       640: 100% 36/36 [05:47<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.80s/it]
#                  all         28         28      0.747      0.857      0.857      0.388
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/34        0G   0.03578   0.01471         0         9       640: 100% 36/36 [05:44<00:00,  9.58s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.66s/it]
#                  all         28         28       0.78      0.888       0.85      0.375
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/34        0G   0.03333   0.01325         0         9       640: 100% 36/36 [05:42<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.70s/it]
#                  all         28         28      0.751      0.821      0.832      0.357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/34        0G   0.03538   0.01377         0         6       640: 100% 36/36 [05:42<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.67s/it]
#                  all         28         28      0.819      0.857      0.849       0.36
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/34        0G   0.03179    0.0135         0         7       640: 100% 36/36 [05:42<00:00,  9.53s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.67s/it]
#                  all         28         28      0.814      0.781      0.833      0.367
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/34        0G   0.03288   0.01322         0         5       640: 100% 36/36 [05:44<00:00,  9.58s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.64s/it]
#                  all         28         28        0.8      0.857      0.855      0.365
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/34        0G    0.0325   0.01337         0         8       640: 100% 36/36 [05:42<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.69s/it]
#                  all         28         28      0.723      0.839      0.831      0.387
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/34        0G   0.03254   0.01362         0         7       640: 100% 36/36 [05:50<00:00,  9.74s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.76s/it]
#                  all         28         28      0.804      0.857      0.878      0.407
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/34        0G   0.03412   0.01309         0         3       640: 100% 36/36 [05:46<00:00,  9.64s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.95s/it]
#                  all         28         28      0.836      0.914      0.888      0.402
#
# 35 epochs completed in 3.549 hours.
# Optimizer stripped from runs/train/exp5/weights/last.pt, 14.5MB
# Optimizer stripped from runs/train/exp5/weights/best.pt, 14.5MB
#
# Validating runs/train/exp5/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:11<00:00,  5.85s/it]
#                  all         28         28      0.804      0.857      0.878      0.407
# Results saved to runs/train/exp5

# %% [markdown]
# ## 3. Detection
#
# Live detection in a video using Yolo-V5
# The video must be uploaded to the runtime and the argument (source path) must be modified accordingly.

# %%
# !python detect.py --weights runs/train/exp5/weights/best.pt --img 640 --conf 0.42 --source ../pen_test.mp4
# Out:
# detect: weights=['runs/train/exp5/weights/best.pt'], source=../pen_test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.42, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-394-gd7bc5d7 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.237s)
# video 1/1 (2/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (3/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (4/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (5/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (6/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (7/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (8/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (9/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (10/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.230s)
# video 1/1 (11/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (12/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (13/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (14/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.209s)
# video 1/1 (15/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (16/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (17/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (18/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (19/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (20/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (21/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (22/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (23/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (24/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (25/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (26/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (27/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (28/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (29/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (30/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (31/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (32/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (33/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (34/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (35/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (36/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (37/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (38/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (39/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (40/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (41/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (42/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.232s)
# video 1/1 (43/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (44/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (45/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (46/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (47/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (48/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (49/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (50/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (51/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (52/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (53/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (54/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (55/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (56/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (57/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (58/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (59/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (60/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (61/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (62/615) /content/pen_test.mp4: 640x384 Done. (0.208s)
# video 1/1 (63/615) /content/pen_test.mp4: 640x384 Done. (0.209s)
# video 1/1 (64/615) /content/pen_test.mp4: 640x384 Done. (0.223s)
# video 1/1 (65/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (66/615) /content/pen_test.mp4: 640x384 Done. (0.218s)
# video 1/1 (67/615) /content/pen_test.mp4: 640x384 Done. (0.211s)
# video 1/1 (68/615) /content/pen_test.mp4: 640x384 Done. (0.223s)
# video 1/1 (69/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (70/615) /content/pen_test.mp4: 640x384 Done. (0.211s)
# video 1/1 (71/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (72/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (73/615) /content/pen_test.mp4: 640x384 Done. (0.220s)
# video 1/1 (74/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (75/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (76/615) /content/pen_test.mp4: 640x384 Done. (0.220s)
# video 1/1 (77/615) /content/pen_test.mp4: 640x384 Done. (0.223s)
# video 1/1 (78/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (79/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (80/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (81/615) /content/pen_test.mp4: 640x384 Done. (0.220s)
# video 1/1 (82/615) /content/pen_test.mp4: 640x384 Done. (0.223s)
# video 1/1 (83/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (84/615) /content/pen_test.mp4: 640x384 Done. (0.209s)
# video 1/1 (85/615) /content/pen_test.mp4: 640x384 Done. (0.218s)
# video 1/1 (86/615) /content/pen_test.mp4: 640x384 Done. (0.224s)
# video 1/1 (87/615) /content/pen_test.mp4: 640x384 Done. (0.221s)
# video 1/1 (88/615) /content/pen_test.mp4: 640x384 Done. (0.227s)
# video 1/1 (89/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (90/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (91/615) /content/pen_test.mp4: 640x384 Done. (0.223s)
# video 1/1 (92/615) /content/pen_test.mp4: 640x384 Done. (0.210s)
# video 1/1 (93/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (94/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (95/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (96/615) /content/pen_test.mp4: 640x384 Done. (0.221s)
# video 1/1 (97/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (98/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (99/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (100/615) /content/pen_test.mp4: 640x384 Done. (0.222s)
# video 1/1 (101/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (102/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (103/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (104/615) /content/pen_test.mp4: 640x384 Done. (0.221s)
# video 1/1 (105/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (106/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (107/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (108/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (109/615) /content/pen_test.mp4: 640x384 Done. (0.224s)
# video 1/1 (110/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (111/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (112/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (113/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (114/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (115/615) /content/pen_test.mp4: 640x384 Done. (0.222s)
# video 1/1 (116/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (117/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (118/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (119/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (120/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (121/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (122/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (123/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (124/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (125/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (126/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (127/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (128/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (129/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (130/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (131/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (132/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (133/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (134/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (135/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (136/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (137/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (138/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (139/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (140/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (141/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (142/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (143/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (144/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (145/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (146/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (147/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (148/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (149/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (150/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (151/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (152/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (153/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (154/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (155/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (156/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (157/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (158/615) /content/pen_test.mp4: 640x384 Done. (0.226s)
# video 1/1 (159/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (160/615) /content/pen_test.mp4: 640x384 Done. (0.218s)
# video 1/1 (161/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (162/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (163/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (164/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (165/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (166/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (167/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (168/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (169/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (170/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (171/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (172/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (173/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (174/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (175/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (176/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (177/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (178/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (179/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (180/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (181/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (182/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (183/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (184/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (185/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (186/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (187/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (188/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (189/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (190/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (191/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (192/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (193/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (194/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (195/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (196/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (197/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (198/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (199/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (200/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (201/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (202/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (203/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (204/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (205/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (206/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (207/615) /content/pen_test.mp4: 640x384 Done. (0.222s)
# video 1/1 (208/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (209/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (210/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (211/615) /content/pen_test.mp4: 640x384 Done. (0.235s)
# video 1/1 (212/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (213/615) /content/pen_test.mp4: 640x384 Done. (0.218s)
# video 1/1 (214/615) /content/pen_test.mp4: 640x384 Done. (0.221s)
# video 1/1 (215/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (216/615) /content/pen_test.mp4: 640x384 Done. (0.225s)
# video 1/1 (217/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (218/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (219/615) /content/pen_test.mp4: 640x384 Done. (0.212s)
# video 1/1 (220/615) /content/pen_test.mp4: 640x384 Done. (0.226s)
# video 1/1 (221/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (222/615) /content/pen_test.mp4: 640x384 Done. (0.216s)
# video 1/1 (223/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (224/615) /content/pen_test.mp4: 640x384 Done. (0.219s)
# video 1/1 (225/615) /content/pen_test.mp4: 640x384 Done. (0.224s)
# video 1/1 (226/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (227/615) /content/pen_test.mp4: 640x384 Done. (0.240s)
# video 1/1 (228/615) /content/pen_test.mp4: 640x384 Done. (0.213s)
# video 1/1 (229/615) /content/pen_test.mp4: 640x384 Done. (0.224s)
# video 1/1 (230/615) /content/pen_test.mp4: 640x384 Done. (0.210s)
# video 1/1 (231/615) /content/pen_test.mp4: 640x384 Done. (0.210s)
# video 1/1 (232/615) /content/pen_test.mp4: 640x384 Done. (0.217s)
# video 1/1 (233/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (234/615) /content/pen_test.mp4: 640x384 Done. (0.227s)
# video 1/1 (235/615) /content/pen_test.mp4: 640x384 Done. (0.215s)
# video 1/1 (236/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (237/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (238/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (239/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (240/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (241/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (242/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (243/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (244/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (245/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (246/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (247/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (248/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (249/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (250/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (251/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (252/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (253/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (254/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (255/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (256/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (257/615) /content/pen_test.mp4: 640x384 Done. (0.226s)
# video 1/1 (258/615) /content/pen_test.mp4: 640x384 Done. (0.229s)
# video 1/1 (259/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.228s)
# video 1/1 (260/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.239s)
# video 1/1 (261/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.218s)
# video 1/1 (262/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (263/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.222s)
# video 1/1 (264/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.224s)
# video 1/1 (265/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (266/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (267/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (268/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (269/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (270/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (271/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (272/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.237s)
# video 1/1 (273/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.225s)
# video 1/1 (274/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (275/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.220s)
# video 1/1 (276/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.221s)
# video 1/1 (277/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (278/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.227s)
# video 1/1 (279/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.223s)
# video 1/1 (280/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.225s)
# video 1/1 (281/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.222s)
# video 1/1 (282/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.233s)
# video 1/1 (283/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.218s)
# video 1/1 (284/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.211s)
# video 1/1 (285/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.220s)
# video 1/1 (286/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.222s)
# video 1/1 (287/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.214s)
# video 1/1 (288/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.218s)
# video 1/1 (289/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.211s)
# video 1/1 (290/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.212s)
# video 1/1 (291/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.220s)
# video 1/1 (292/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.212s)
# video 1/1 (293/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.217s)
# video 1/1 (294/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.209s)
# video 1/1 (295/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.224s)
# video 1/1 (296/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.212s)
# video 1/1 (297/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.216s)
# video 1/1 (298/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.213s)
# video 1/1 (299/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.214s)
# video 1/1 (300/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.222s)
# video 1/1 (301/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.220s)
# video 1/1 (302/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.219s)
# video 1/1 (303/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (304/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (305/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (306/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (307/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (308/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (309/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (310/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (311/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (312/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (313/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (314/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (315/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (316/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (317/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (318/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.237s)
# video 1/1 (319/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (320/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (321/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (322/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (323/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (324/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (325/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (326/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (327/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (328/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (329/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (330/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (331/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (332/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (333/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (334/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (335/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (336/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (337/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (338/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (339/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (340/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (341/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (342/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (343/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (344/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (345/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (346/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (347/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (348/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (349/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (350/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (351/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (352/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (353/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (354/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (355/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (356/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (357/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (358/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (359/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (360/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (361/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (362/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (363/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (364/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (365/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (366/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (367/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (368/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (369/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (370/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.208s)
# video 1/1 (371/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (372/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.208s)
# video 1/1 (373/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (374/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (375/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (376/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (377/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (378/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (379/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (380/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (381/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (382/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (383/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.209s)
# video 1/1 (384/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (385/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (386/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (387/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (388/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (389/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (390/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (391/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.220s)
# video 1/1 (392/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (393/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (394/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.207s)
# video 1/1 (395/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (396/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (397/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (398/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.230s)
# video 1/1 (399/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (400/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (401/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (402/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (403/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (404/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (405/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (406/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (407/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (408/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (409/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (410/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.231s)
# video 1/1 (411/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.229s)
# video 1/1 (412/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (413/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (414/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (415/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (416/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (417/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (418/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (419/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (420/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (421/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (422/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (423/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (424/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (425/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (426/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (427/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (428/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (429/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (430/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.209s)
# video 1/1 (431/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (432/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.210s)
# video 1/1 (433/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (434/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (435/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (436/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.218s)
# video 1/1 (437/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (438/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.230s)
# video 1/1 (439/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (440/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (441/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (442/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (443/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (444/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (445/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (446/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (447/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (448/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.211s)
# video 1/1 (449/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.215s)
# video 1/1 (450/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.214s)
# video 1/1 (451/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.212s)
# video 1/1 (452/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.219s)
# video 1/1 (453/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.209s)
# video 1/1 (454/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.216s)
# video 1/1 (455/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.209s)
# video 1/1 (456/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.236s)
# video 1/1 (457/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.208s)
# video 1/1 (458/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (459/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (460/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (461/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (462/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (463/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (464/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (465/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (466/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (467/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (468/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (469/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (470/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.210s)
# video 1/1 (471/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (472/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (473/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (474/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (475/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (476/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (477/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (478/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (479/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.208s)
# video 1/1 (480/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (481/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (482/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (483/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (484/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (485/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (486/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (487/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (488/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (489/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (490/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (491/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.215s)
# video 1/1 (492/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (493/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.214s)
# video 1/1 (494/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (495/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (496/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (497/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (498/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (499/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (500/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (501/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (502/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.238s)
# video 1/1 (503/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (504/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (505/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (506/615) /content/pen_test.mp4: 640x384 Done. (0.225s)
# video 1/1 (507/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (508/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (509/615) /content/pen_test.mp4: 640x384 Done. (0.222s)
# video 1/1 (510/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (511/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (512/615) /content/pen_test.mp4: 640x384 Done. (0.214s)
# video 1/1 (513/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (514/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (515/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (516/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (517/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (518/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (519/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (520/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (521/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (522/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (523/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (524/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (525/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (526/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (527/615) /content/pen_test.mp4: 640x384 Done. (0.227s)
# video 1/1 (528/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (529/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (530/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (531/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (532/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (533/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.218s)
# video 1/1 (534/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.224s)
# video 1/1 (535/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (536/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.225s)
# video 1/1 (537/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (538/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.212s)
# video 1/1 (539/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (540/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.224s)
# video 1/1 (541/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.216s)
# video 1/1 (542/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (543/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (544/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (545/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (546/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (547/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.234s)
# video 1/1 (548/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (549/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (550/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (551/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (552/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (553/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (554/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (555/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (556/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (557/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.215s)
# video 1/1 (558/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (559/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (560/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (561/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (562/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (563/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (564/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (565/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (566/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.213s)
# video 1/1 (567/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (568/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (569/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (570/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (571/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (572/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (573/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.217s)
# video 1/1 (574/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.209s)
# video 1/1 (575/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (576/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (577/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (578/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (579/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (580/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (581/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.218s)
# video 1/1 (582/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (583/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (584/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (585/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (586/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.222s)
# video 1/1 (587/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (588/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (589/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.224s)
# video 1/1 (590/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (591/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (592/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (593/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (594/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (595/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (596/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (597/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (598/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.223s)
# video 1/1 (599/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (600/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.219s)
# video 1/1 (601/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (602/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.228s)
# video 1/1 (603/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.219s)
# video 1/1 (604/615) /content/pen_test.mp4: 640x384 2 pens, Done. (0.216s)
# video 1/1 (605/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (606/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.226s)
# video 1/1 (607/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.220s)
# video 1/1 (608/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.221s)
# video 1/1 (609/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.216s)
# video 1/1 (610/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.215s)
# video 1/1 (611/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# video 1/1 (612/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.217s)
# video 1/1 (613/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.214s)
# video 1/1 (614/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.211s)
# video 1/1 (615/615) /content/pen_test.mp4: 640x384 1 pen, Done. (0.227s)
# Speed: 1.2ms pre-process, 217.8ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12
